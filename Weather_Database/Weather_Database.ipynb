# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 761

# %%
#Import dependencies
import requests
from config import g_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + g_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | auki
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | mount gambier
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | outjo
# Processing Record 9 of Set 1 | sitka
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | bathsheba
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | el dorado
# Processing Record 15 of Set 1 | springdale
# Processing Record 16 of Set 1 | angoche
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | omboue
# Processing Record 19 of Set 1 | karratha
# Processing Record 20 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 1 | lompoc
# Processing Record 22 of Set 1 | garowe
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | te anau
# Processing Record 25 of Set 1 | bandarbeyla
# Processing Record 26 of Set 1 | ayan
# Processing Record 27 of Set 1 | cidreira
# Processing Record 28 of Set 1 | suzun
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | poum
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | arman
# Processing Record 33 of Set 1 | nanma
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | treinta y tres
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | puerto penasco
# Processing Record 40 of Set 1 | talara
# Processing Record 41 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | rtishchevo
# Processing Record 45 of Set 1 | dengzhou
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | paamiut
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | dibulla
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | codrington
# Processing Record 8 of Set 2 | harper
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | lalomanu
# City not found. Skipping...
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | saint-georges
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | sol-iletsk
# Processing Record 18 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | sola
# Processing Record 21 of Set 2 | the valley
# Processing Record 22 of Set 2 | masuda
# Processing Record 23 of Set 2 | jacqueville
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | svetlogorsk
# Processing Record 26 of Set 2 | sibolga
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | chuy
# Processing Record 29 of Set 2 | fortuna
# Processing Record 30 of Set 2 | haines junction
# Processing Record 31 of Set 2 | chivay
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | manicore
# Processing Record 34 of Set 2 | hofn
# Processing Record 35 of Set 2 | voi
# Processing Record 36 of Set 2 | fredericksburg
# Processing Record 37 of Set 2 | luganville
# Processing Record 38 of Set 2 | rorvik
# Processing Record 39 of Set 2 | gogrial
# Processing Record 40 of Set 2 | aksu
# Processing Record 41 of Set 2 | plotnikovo
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | ambilobe
# Processing Record 44 of Set 2 | namibe
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | ntchisi
# Processing Record 48 of Set 2 | tazovskiy
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | jorochito
# Processing Record 2 of Set 3 | mikhaylovskoye
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | vila
# Processing Record 5 of Set 3 | lorengau
# Processing Record 6 of Set 3 | nelson bay
# Processing Record 7 of Set 3 | albany
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | shchelyayur
# City not found. Skipping...
# Processing Record 10 of Set 3 | milos
# Processing Record 11 of Set 3 | kharp
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | guerrero negro
# Processing Record 14 of Set 3 | lakhimpur
# Processing Record 15 of Set 3 | ibra
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | tadine
# Processing Record 18 of Set 3 | pochinok
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | chateaubelair
# Processing Record 21 of Set 3 | prince rupert
# Processing Record 22 of Set 3 | grindavik
# Processing Record 23 of Set 3 | krasnoselkup
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | pijijiapan
# Processing Record 26 of Set 3 | lazaro cardenas
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | tongren
# Processing Record 29 of Set 3 | okha
# Processing Record 30 of Set 3 | gat
# Processing Record 31 of Set 3 | makakilo city
# Processing Record 32 of Set 3 | olafsvik
# Processing Record 33 of Set 3 | new norfolk
# Processing Record 34 of Set 3 | marawi
# Processing Record 35 of Set 3 | flagstaff
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | mangrol
# Processing Record 38 of Set 3 | salinopolis
# Processing Record 39 of Set 3 | kamaishi
# Processing Record 40 of Set 3 | jibuti
# Processing Record 41 of Set 3 | ahipara
# Processing Record 42 of Set 3 | kirakira
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | izhma
# Processing Record 45 of Set 3 | burnie
# Processing Record 46 of Set 3 | villanueva de la serena
# Processing Record 47 of Set 3 | horasan
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | carbonia
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | inongo
# Processing Record 2 of Set 4 | bethel
# Processing Record 3 of Set 4 | shimizu
# Processing Record 4 of Set 4 | meulaboh
# Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 4 | tres passos
# Processing Record 7 of Set 4 | gifhorn
# Processing Record 8 of Set 4 | miranorte
# City not found. Skipping...
# Processing Record 9 of Set 4 | voh
# Processing Record 10 of Set 4 | lensk
# Processing Record 11 of Set 4 | kachug
# Processing Record 12 of Set 4 | aklavik
# Processing Record 13 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 4 | manaure
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | gurmatkal
# Processing Record 17 of Set 4 | burica
# City not found. Skipping...
# Processing Record 18 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | dudinka
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | prata
# Processing Record 23 of Set 4 | adrar
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | verkhoyansk
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | whitianga
# Processing Record 28 of Set 4 | lavrentiya
# Processing Record 29 of Set 4 | chicama
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | sarangani
# Processing Record 32 of Set 4 | gumdag
# Processing Record 33 of Set 4 | chubbuck
# Processing Record 34 of Set 4 | vao
# Processing Record 35 of Set 4 | marzuq
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | miri
# Processing Record 38 of Set 4 | waipawa
# Processing Record 39 of Set 4 | cockburn town
# Processing Record 40 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 4 | ambon
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | alice town
# Processing Record 45 of Set 4 | dogondoutchi
# Processing Record 46 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 4 | slobidka
# Processing Record 48 of Set 4 | baijiantan
# Processing Record 49 of Set 4 | hami
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | mabaruma
# Processing Record 2 of Set 5 | chernyshevskiy
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | wabana
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | malindi
# Processing Record 7 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 5 | sarmizegetusa
# Processing Record 9 of Set 5 | bonavista
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | jucuaran
# Processing Record 12 of Set 5 | bambous virieux
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | husavik
# Processing Record 15 of Set 5 | tateyama
# Processing Record 16 of Set 5 | ayagoz
# Processing Record 17 of Set 5 | oistins
# Processing Record 18 of Set 5 | bodden town
# Processing Record 19 of Set 5 | honningsvag
# Processing Record 20 of Set 5 | santo antonio do ica
# Processing Record 21 of Set 5 | cherskiy
# Processing Record 22 of Set 5 | xingcheng
# Processing Record 23 of Set 5 | bemidji
# Processing Record 24 of Set 5 | palmer
# Processing Record 25 of Set 5 | sangar
# Processing Record 26 of Set 5 | vila franca do campo
# Processing Record 27 of Set 5 | zhanaozen
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | ambulu
# Processing Record 30 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | choix
# Processing Record 33 of Set 5 | buraydah
# Processing Record 34 of Set 5 | phrai bung
# City not found. Skipping...
# Processing Record 35 of Set 5 | qasigiannguit
# Processing Record 36 of Set 5 | scalea
# Processing Record 37 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 5 | nome
# Processing Record 39 of Set 5 | kosh-agach
# Processing Record 40 of Set 5 | quang ngai
# Processing Record 41 of Set 5 | ocos
# Processing Record 42 of Set 5 | college
# Processing Record 43 of Set 5 | cartagena del chaira
# Processing Record 44 of Set 5 | hailar
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | aktau
# Processing Record 47 of Set 5 | santiago de cao
# Processing Record 48 of Set 5 | skjervoy
# Processing Record 49 of Set 5 | kodinsk
# Processing Record 50 of Set 5 | nokaneng
# Processing Record 1 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 2 of Set 6 | minas novas
# Processing Record 3 of Set 6 | ulladulla
# Processing Record 4 of Set 6 | shimoda
# Processing Record 5 of Set 6 | hirara
# Processing Record 6 of Set 6 | vikhorevka
# Processing Record 7 of Set 6 | schruns
# Processing Record 8 of Set 6 | nettuno
# Processing Record 9 of Set 6 | vostok
# Processing Record 10 of Set 6 | ciudad real
# Processing Record 11 of Set 6 | bandrele
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | ostrovnoy
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | cocobeach
# Processing Record 16 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 6 | sept-iles
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | westport
# Processing Record 21 of Set 6 | katobu
# Processing Record 22 of Set 6 | walvis bay
# Processing Record 23 of Set 6 | hobart
# Processing Record 24 of Set 6 | langxiang
# Processing Record 25 of Set 6 | ancud
# Processing Record 26 of Set 6 | davila
# Processing Record 27 of Set 6 | provideniya
# Processing Record 28 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 29 of Set 6 | belogorsk
# Processing Record 30 of Set 6 | yaan
# Processing Record 31 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 6 | praia da vitoria
# Processing Record 33 of Set 6 | port-gentil
# Processing Record 34 of Set 6 | port blair
# Processing Record 35 of Set 6 | misratah
# Processing Record 36 of Set 6 | katsuura
# Processing Record 37 of Set 6 | saskylakh
# Processing Record 38 of Set 6 | novobirilyussy
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | conceicao da barra
# Processing Record 41 of Set 6 | ahuimanu
# Processing Record 42 of Set 6 | clarence town
# Processing Record 43 of Set 6 | dakar
# Processing Record 44 of Set 6 | riyadh
# Processing Record 45 of Set 6 | niksar
# Processing Record 46 of Set 6 | victoria
# Processing Record 47 of Set 6 | axim
# Processing Record 48 of Set 6 | agirish
# Processing Record 49 of Set 6 | torit
# Processing Record 50 of Set 6 | uk
# City not found. Skipping...
# Processing Record 1 of Set 7 | gimbi
# Processing Record 2 of Set 7 | veraval
# Processing Record 3 of Set 7 | port pirie
# Processing Record 4 of Set 7 | mount isa
# Processing Record 5 of Set 7 | cabo san lucas
# Processing Record 6 of Set 7 | norrtalje
# Processing Record 7 of Set 7 | itaituba
# Processing Record 8 of Set 7 | krasnyy chikoy
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | thompson
# Processing Record 11 of Set 7 | uyuni
# Processing Record 12 of Set 7 | wanxian
# Processing Record 13 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 7 | rupert
# Processing Record 15 of Set 7 | linjiang
# Processing Record 16 of Set 7 | peniche
# Processing Record 17 of Set 7 | solnechnyy
# Processing Record 18 of Set 7 | sao filipe
# Processing Record 19 of Set 7 | lugo
# Processing Record 20 of Set 7 | panama city
# Processing Record 21 of Set 7 | sovetskiy
# Processing Record 22 of Set 7 | kulhudhuffushi
# Processing Record 23 of Set 7 | mirnyy
# Processing Record 24 of Set 7 | salalah
# Processing Record 25 of Set 7 | saint george
# Processing Record 26 of Set 7 | goderich
# Processing Record 27 of Set 7 | obzor
# Processing Record 28 of Set 7 | pevek
# Processing Record 29 of Set 7 | saint-pierre
# Processing Record 30 of Set 7 | manta
# Processing Record 31 of Set 7 | maniitsoq
# Processing Record 32 of Set 7 | sosnogorsk
# Processing Record 33 of Set 7 | tiksi
# Processing Record 34 of Set 7 | tremedal
# Processing Record 35 of Set 7 | san carlos
# Processing Record 36 of Set 7 | vardo
# Processing Record 37 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 7 | serrana
# Processing Record 39 of Set 7 | shirokiy
# Processing Record 40 of Set 7 | tampere
# Processing Record 41 of Set 7 | marrakesh
# Processing Record 42 of Set 7 | alofi
# Processing Record 43 of Set 7 | bubaque
# Processing Record 44 of Set 7 | fare
# Processing Record 45 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 7 | luz
# Processing Record 47 of Set 7 | pucallpa
# Processing Record 48 of Set 7 | biltine
# Processing Record 49 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 7 | tsabong
# Processing Record 1 of Set 8 | puerto del rosario
# Processing Record 2 of Set 8 | tuatapere
# Processing Record 3 of Set 8 | okmulgee
# Processing Record 4 of Set 8 | sur
# Processing Record 5 of Set 8 | teneguiban
# City not found. Skipping...
# Processing Record 6 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 8 | piacabucu
# Processing Record 8 of Set 8 | mehamn
# Processing Record 9 of Set 8 | karasjok
# Processing Record 10 of Set 8 | decatur
# Processing Record 11 of Set 8 | labuhan
# Processing Record 12 of Set 8 | hobbs
# Processing Record 13 of Set 8 | toulepleu
# City not found. Skipping...
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | kloulklubed
# Processing Record 16 of Set 8 | kaeo
# Processing Record 17 of Set 8 | manono
# Processing Record 18 of Set 8 | vossevangen
# Processing Record 19 of Set 8 | develi
# Processing Record 20 of Set 8 | itarana
# Processing Record 21 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 8 | berberati
# Processing Record 23 of Set 8 | ostrow wielkopolski
# Processing Record 24 of Set 8 | san rafael
# Processing Record 25 of Set 8 | telimele
# Processing Record 26 of Set 8 | marand
# Processing Record 27 of Set 8 | tyrma
# Processing Record 28 of Set 8 | kresttsy
# Processing Record 29 of Set 8 | siyabuswa
# Processing Record 30 of Set 8 | bagdarin
# Processing Record 31 of Set 8 | belyy yar
# Processing Record 32 of Set 8 | floresta
# Processing Record 33 of Set 8 | pacific grove
# Processing Record 34 of Set 8 | isangel
# Processing Record 35 of Set 8 | ola
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | adre
# Processing Record 38 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 8 | saint anthony
# Processing Record 40 of Set 8 | sorland
# Processing Record 41 of Set 8 | balabac
# Processing Record 42 of Set 8 | san pedro de macoris
# Processing Record 43 of Set 8 | northam
# Processing Record 44 of Set 8 | desbiens
# Processing Record 45 of Set 8 | saint marys
# Processing Record 46 of Set 8 | ballina
# Processing Record 47 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 8 | sosnovo-ozerskoye
# Processing Record 49 of Set 8 | metro
# Processing Record 50 of Set 8 | yeppoon
# Processing Record 1 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 9 | saint john
# Processing Record 3 of Set 9 | calabozo
# Processing Record 4 of Set 9 | mopipi
# Processing Record 5 of Set 9 | birao
# Processing Record 6 of Set 9 | kuzhithurai
# Processing Record 7 of Set 9 | sibu
# Processing Record 8 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 9 | jaumave
# Processing Record 10 of Set 9 | snezhnogorsk
# Processing Record 11 of Set 9 | bengkulu
# Processing Record 12 of Set 9 | port hedland
# Processing Record 13 of Set 9 | bilma
# Processing Record 14 of Set 9 | iqaluit
# Processing Record 15 of Set 9 | vanavara
# Processing Record 16 of Set 9 | vizinga
# Processing Record 17 of Set 9 | matagami
# Processing Record 18 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 9 | barsovo
# Processing Record 20 of Set 9 | tutoia
# Processing Record 21 of Set 9 | tonekabon
# Processing Record 22 of Set 9 | cocachacra
# Processing Record 23 of Set 9 | custodia
# Processing Record 24 of Set 9 | visnes
# Processing Record 25 of Set 9 | oxford
# Processing Record 26 of Set 9 | san patricio
# Processing Record 27 of Set 9 | fort nelson
# Processing Record 28 of Set 9 | batouri
# Processing Record 29 of Set 9 | severo-kurilsk
# Processing Record 30 of Set 9 | palm coast
# Processing Record 31 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 32 of Set 9 | kichera
# Processing Record 33 of Set 9 | porto
# Processing Record 34 of Set 9 | bealanana
# Processing Record 35 of Set 9 | luoyang
# Processing Record 36 of Set 9 | qarqin
# Processing Record 37 of Set 9 | lisakovsk
# Processing Record 38 of Set 9 | korla
# Processing Record 39 of Set 9 | baymak
# Processing Record 40 of Set 9 | fomboni
# Processing Record 41 of Set 9 | ornskoldsvik
# Processing Record 42 of Set 9 | gwanda
# Processing Record 43 of Set 9 | araouane
# Processing Record 44 of Set 9 | anadyr
# Processing Record 45 of Set 9 | zemio
# Processing Record 46 of Set 9 | zyryanka
# Processing Record 47 of Set 9 | comodoro rivadavia
# Processing Record 48 of Set 9 | acapulco
# Processing Record 49 of Set 9 | aspindza
# Processing Record 50 of Set 9 | fatikchhari
# City not found. Skipping...
# Processing Record 1 of Set 10 | lhanbryde
# Processing Record 2 of Set 10 | colac
# Processing Record 3 of Set 10 | novaya lyalya
# Processing Record 4 of Set 10 | evensk
# Processing Record 5 of Set 10 | atambua
# Processing Record 6 of Set 10 | melfi
# Processing Record 7 of Set 10 | mikrokambos
# Processing Record 8 of Set 10 | hovd
# Processing Record 9 of Set 10 | emba
# Processing Record 10 of Set 10 | bereznik
# Processing Record 11 of Set 10 | boa vista
# Processing Record 12 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 10 | pangody
# Processing Record 14 of Set 10 | melito di porto salvo
# Processing Record 15 of Set 10 | betki
# City not found. Skipping...
# Processing Record 16 of Set 10 | igarka
# Processing Record 17 of Set 10 | plonsk
# Processing Record 18 of Set 10 | jalu
# Processing Record 19 of Set 10 | prainha
# Processing Record 20 of Set 10 | andenes
# Processing Record 21 of Set 10 | mogadishu
# Processing Record 22 of Set 10 | arklow
# Processing Record 23 of Set 10 | avera
# Processing Record 24 of Set 10 | kletnya
# Processing Record 25 of Set 10 | phan thiet
# Processing Record 26 of Set 10 | camacha
# Processing Record 27 of Set 10 | bam
# Processing Record 28 of Set 10 | nyurba
# Processing Record 29 of Set 10 | mehriz
# Processing Record 30 of Set 10 | sisimiut
# Processing Record 31 of Set 10 | nantucket
# Processing Record 32 of Set 10 | ordynskoye
# Processing Record 33 of Set 10 | half moon bay
# Processing Record 34 of Set 10 | puerto gaitan
# Processing Record 35 of Set 10 | fort-shevchenko
# Processing Record 36 of Set 10 | san angelo
# Processing Record 37 of Set 10 | wadern
# Processing Record 38 of Set 10 | sokoni
# Processing Record 39 of Set 10 | buta
# Processing Record 40 of Set 10 | witu
# Processing Record 41 of Set 10 | samagaltay
# Processing Record 42 of Set 10 | colares
# Processing Record 43 of Set 10 | nanortalik
# Processing Record 44 of Set 10 | asau
# Processing Record 45 of Set 10 | bridgewater
# Processing Record 46 of Set 10 | itarema
# Processing Record 47 of Set 10 | amuntai
# Processing Record 48 of Set 10 | muli
# Processing Record 49 of Set 10 | bundaberg
# Processing Record 50 of Set 10 | lively
# Processing Record 1 of Set 11 | cochrane
# Processing Record 2 of Set 11 | burgeo
# Processing Record 3 of Set 11 | dunda
# Processing Record 4 of Set 11 | erechim
# Processing Record 5 of Set 11 | longyearbyen
# Processing Record 6 of Set 11 | saint austell
# Processing Record 7 of Set 11 | tecoanapa
# Processing Record 8 of Set 11 | sistranda
# Processing Record 9 of Set 11 | mitsamiouli
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | sao miguel
# Processing Record 12 of Set 11 | les cayes
# Processing Record 13 of Set 11 | den helder
# Processing Record 14 of Set 11 | port moresby
# Processing Record 15 of Set 11 | anton lizardo
# Processing Record 16 of Set 11 | dunedin
# Processing Record 17 of Set 11 | umm lajj
# Processing Record 18 of Set 11 | shakawe
# Processing Record 19 of Set 11 | havoysund
# Processing Record 20 of Set 11 | yilan
# Processing Record 21 of Set 11 | aksha
# Processing Record 22 of Set 11 | atar
# Processing Record 23 of Set 11 | naryan-mar
# Processing Record 24 of Set 11 | rio gallegos
# Processing Record 25 of Set 11 | garissa
# Processing Record 26 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 11 | bose
# Processing Record 28 of Set 11 | syracuse
# Processing Record 29 of Set 11 | yetkul
# Processing Record 30 of Set 11 | arenapolis
# Processing Record 31 of Set 11 | pangoa
# Processing Record 32 of Set 11 | seoul
# Processing Record 33 of Set 11 | broome
# Processing Record 34 of Set 11 | kijang
# Processing Record 35 of Set 11 | katubao
# Processing Record 36 of Set 11 | la grande
# Processing Record 37 of Set 11 | xianshuigu
# Processing Record 38 of Set 11 | kamakhyanagar
# Processing Record 39 of Set 11 | luang prabang
# Processing Record 40 of Set 11 | manacapuru
# Processing Record 41 of Set 11 | saraza
# Processing Record 42 of Set 11 | nuuk
# Processing Record 43 of Set 11 | kholodnyy
# Processing Record 44 of Set 11 | kashi
# Processing Record 45 of Set 11 | eureka
# Processing Record 46 of Set 11 | menongue
# Processing Record 47 of Set 11 | bauchi
# Processing Record 48 of Set 11 | san juan de arama
# Processing Record 49 of Set 11 | hermon
# Processing Record 50 of Set 11 | doha
# Processing Record 1 of Set 12 | illapel
# Processing Record 2 of Set 12 | skelleftea
# Processing Record 3 of Set 12 | najran
# Processing Record 4 of Set 12 | shivrajpur
# Processing Record 5 of Set 12 | katherine
# Processing Record 6 of Set 12 | chiredzi
# Processing Record 7 of Set 12 | tikapur
# Processing Record 8 of Set 12 | mwanza
# Processing Record 9 of Set 12 | kauhajoki
# Processing Record 10 of Set 12 | ketchikan
# Processing Record 11 of Set 12 | carutapera
# Processing Record 12 of Set 12 | novouzensk
# Processing Record 13 of Set 12 | plettenberg bay
# Processing Record 14 of Set 12 | okhotsk
# Processing Record 15 of Set 12 | pilar
# Processing Record 16 of Set 12 | udala
# Processing Record 17 of Set 12 | yulara
# Processing Record 18 of Set 12 | alice springs
# Processing Record 19 of Set 12 | brigantine
# Processing Record 20 of Set 12 | horconcitos
# Processing Record 21 of Set 12 | tilichiki
# Processing Record 22 of Set 12 | jojoima
# Processing Record 23 of Set 12 | zorritos
# Processing Record 24 of Set 12 | pasaje
# Processing Record 25 of Set 12 | batagay
# Processing Record 26 of Set 12 | kamarion
# Processing Record 27 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 12 | phumi samraong
# City not found. Skipping...
# Processing Record 29 of Set 12 | itoman
# Processing Record 30 of Set 12 | imperial beach
# Processing Record 31 of Set 12 | ribeira grande
# Processing Record 32 of Set 12 | shitanjing
# Processing Record 33 of Set 12 | san cristobal
# Processing Record 34 of Set 12 | slave lake
# Processing Record 35 of Set 12 | akureyri
# Processing Record 36 of Set 12 | tignere
# Processing Record 37 of Set 12 | khani
# Processing Record 38 of Set 12 | miechow
# Processing Record 39 of Set 12 | coahuayana
# Processing Record 40 of Set 12 | narsaq
# Processing Record 41 of Set 12 | skoghall
# Processing Record 42 of Set 12 | homer
# Processing Record 43 of Set 12 | nosy varika
# Processing Record 44 of Set 12 | nizhneangarsk
# Processing Record 45 of Set 12 | christchurch
# Processing Record 46 of Set 12 | changde
# Processing Record 47 of Set 12 | buala
# Processing Record 48 of Set 12 | charleston
# Processing Record 49 of Set 12 | magog
# Processing Record 50 of Set 12 | wuwei
# Processing Record 1 of Set 13 | bijapur
# Processing Record 2 of Set 13 | komsomolskiy
# Processing Record 3 of Set 13 | kyren
# Processing Record 4 of Set 13 | fukuma
# Processing Record 5 of Set 13 | vanimo
# Processing Record 6 of Set 13 | celestun
# Processing Record 7 of Set 13 | ilovlya
# Processing Record 8 of Set 13 | natal
# Processing Record 9 of Set 13 | faxinal
# Processing Record 10 of Set 13 | turbat
# Processing Record 11 of Set 13 | oshawa
# Processing Record 12 of Set 13 | necochea
# Processing Record 13 of Set 13 | neka
# Processing Record 14 of Set 13 | upata
# Processing Record 15 of Set 13 | mattru
# Processing Record 16 of Set 13 | panalingaan
# Processing Record 17 of Set 13 | tokur
# Processing Record 18 of Set 13 | lakes entrance
# Processing Record 19 of Set 13 | gizo
# Processing Record 20 of Set 13 | pochutla
# Processing Record 21 of Set 13 | san andres
# Processing Record 22 of Set 13 | muros
# Processing Record 23 of Set 13 | jijiga
# Processing Record 24 of Set 13 | ormara
# Processing Record 25 of Set 13 | champerico
# Processing Record 26 of Set 13 | ponta delgada
# Processing Record 27 of Set 13 | vallenar
# Processing Record 28 of Set 13 | dakoro
# Processing Record 29 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 13 | rabaul
# Processing Record 31 of Set 13 | kano
# Processing Record 32 of Set 13 | saint-augustin
# Processing Record 33 of Set 13 | mecca
# Processing Record 34 of Set 13 | padang
# Processing Record 35 of Set 13 | sansai
# City not found. Skipping...
# Processing Record 36 of Set 13 | nouadhibou
# Processing Record 37 of Set 13 | niquero
# Processing Record 38 of Set 13 | kavaratti
# Processing Record 39 of Set 13 | kushima
# Processing Record 40 of Set 13 | sembe
# Processing Record 41 of Set 13 | panguna
# Processing Record 42 of Set 13 | meadow lake
# Processing Record 43 of Set 13 | dravograd
# Processing Record 44 of Set 13 | tanout
# Processing Record 45 of Set 13 | palana
# Processing Record 46 of Set 13 | guskhara
# Processing Record 47 of Set 13 | maldonado
# Processing Record 48 of Set 13 | langarud
# Processing Record 49 of Set 13 | dalian
# Processing Record 50 of Set 13 | abhar
# Processing Record 1 of Set 14 | polunochnoye
# Processing Record 2 of Set 14 | benjamin aceval
# Processing Record 3 of Set 14 | kimbe
# Processing Record 4 of Set 14 | baykit
# Processing Record 5 of Set 14 | manzhouli
# Processing Record 6 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 14 | tautira
# Processing Record 8 of Set 14 | coihaique
# Processing Record 9 of Set 14 | raudeberg
# Processing Record 10 of Set 14 | keti bandar
# Processing Record 11 of Set 14 | kamskiye polyany
# Processing Record 12 of Set 14 | puerto leguizamo
# Processing Record 13 of Set 14 | aykhal
# Processing Record 14 of Set 14 | chittaurgarh
# Processing Record 15 of Set 14 | zhicheng
# Processing Record 16 of Set 14 | inirida
# Processing Record 17 of Set 14 | rincon
# Processing Record 18 of Set 14 | trinidad
# Processing Record 19 of Set 14 | kurilsk
# Processing Record 20 of Set 14 | kalianget
# Processing Record 21 of Set 14 | raga
# Processing Record 22 of Set 14 | verkhniy baskunchak
# Processing Record 23 of Set 14 | boueni
# Processing Record 24 of Set 14 | centralia
# Processing Record 25 of Set 14 | lagoa
# Processing Record 26 of Set 14 | hambantota
# Processing Record 27 of Set 14 | wazzan
# City not found. Skipping...
# Processing Record 28 of Set 14 | abu dhabi
# Processing Record 29 of Set 14 | coyula
# Processing Record 30 of Set 14 | oranjestad
# Processing Record 31 of Set 14 | wejherowo
# Processing Record 32 of Set 14 | fairbanks
# Processing Record 33 of Set 14 | montepuez
# Processing Record 34 of Set 14 | sao domingos
# Processing Record 35 of Set 14 | stettler
# Processing Record 36 of Set 14 | harbour breton
# Processing Record 37 of Set 14 | fengxian
# Processing Record 38 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 39 of Set 14 | sao joao da barra
# Processing Record 40 of Set 14 | chumikan
# Processing Record 41 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 42 of Set 14 | dhidhdhoo
# Processing Record 43 of Set 14 | viedma
# Processing Record 44 of Set 14 | pirapora do bom jesus
# Processing Record 45 of Set 14 | kifri
# Processing Record 46 of Set 14 | beloha
# Processing Record 47 of Set 14 | yanam
# Processing Record 48 of Set 14 | fukue
# Processing Record 49 of Set 14 | hualmay
# Processing Record 50 of Set 14 | great falls
# Processing Record 1 of Set 15 | suntar
# Processing Record 2 of Set 15 | mineral wells
# Processing Record 3 of Set 15 | kananga
# Processing Record 4 of Set 15 | forestville
# Processing Record 5 of Set 15 | dalbandin
# Processing Record 6 of Set 15 | beringovskiy
# Processing Record 7 of Set 15 | imbituba
# Processing Record 8 of Set 15 | guarapari
# Processing Record 9 of Set 15 | marsa matruh
# Processing Record 10 of Set 15 | taltal
# Processing Record 11 of Set 15 | oussouye
# Processing Record 12 of Set 15 | port hueneme
# Processing Record 13 of Set 15 | trelew
# Processing Record 14 of Set 15 | san remigio
# Processing Record 15 of Set 15 | samarai
# Processing Record 16 of Set 15 | henties bay
# Processing Record 17 of Set 15 | rognedino
# Processing Record 18 of Set 15 | guantanamo
# Processing Record 19 of Set 15 | buriti bravo
# Processing Record 20 of Set 15 | whitehorse
# Processing Record 21 of Set 15 | manggar
# Processing Record 22 of Set 15 | bereda
# Processing Record 23 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 15 | mendi
# Processing Record 25 of Set 15 | freeport
# Processing Record 26 of Set 15 | semey
# Processing Record 27 of Set 15 | buenos aires
# Processing Record 28 of Set 15 | bonfim
# Processing Record 29 of Set 15 | tigil
# Processing Record 30 of Set 15 | mossendjo
# Processing Record 31 of Set 15 | oranjemund
# Processing Record 32 of Set 15 | oktyabrskoye
# Processing Record 33 of Set 15 | presidencia roque saenz pena
# Processing Record 34 of Set 15 | mushabani
# Processing Record 35 of Set 15 | sterling
# Processing Record 36 of Set 15 | zhigalovo
# Processing Record 37 of Set 15 | handan
# Processing Record 38 of Set 15 | kruisfontein
# Processing Record 39 of Set 15 | aksarka
# Processing Record 40 of Set 15 | rocha
# Processing Record 41 of Set 15 | sarata
# Processing Record 42 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 15 | brownwood
# Processing Record 44 of Set 15 | rabak
# Processing Record 45 of Set 15 | otane
# Processing Record 46 of Set 15 | mahon
# Processing Record 47 of Set 15 | zhangjiakou
# Processing Record 48 of Set 15 | srednekolymsk
# Processing Record 49 of Set 15 | sredec
# City not found. Skipping...
# Processing Record 50 of Set 15 | pimentel
# Processing Record 1 of Set 16 | diego de almagro
# Processing Record 2 of Set 16 | buy
# Processing Record 3 of Set 16 | lima
# Processing Record 4 of Set 16 | cap malheureux
# Processing Record 5 of Set 16 | mtwango
# Processing Record 6 of Set 16 | rundu
# Processing Record 7 of Set 16 | tandil
# Processing Record 8 of Set 16 | ugoofaaru
# Processing Record 9 of Set 16 | yumen
# Processing Record 10 of Set 16 | watsa
# Processing Record 11 of Set 16 | zambezi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     73.13        76           4
# 1             Auki      SB  -8.7676  160.7034     86.50        65          85
# 2       Kaitangata      NZ -46.2817  169.8464     56.37        87          93
# 3           Faanui      PF -16.4833 -151.7500     81.46        69          14
# 4    Mount Gambier      AU -37.8333  140.7667     60.31        52         100
# 5       Butaritari      KI   3.0707  172.7902     81.72        79          73
# 6      East London      ZA -33.0153   27.9116     68.94        64           0
# 7            Outjo      NA -20.1167   16.1500     57.45        54          30
# 8            Sitka      US  57.0531 -135.3300     48.09        66          20
# 9          Mataura      NZ -46.1927  168.8643     55.47        98         100
#
#    Wind Speed Current Description
# 0        9.75           clear sky
# 1        3.40     overcast clouds
# 2        9.33       moderate rain
# 3        7.56          few clouds
# 4        7.87     overcast clouds
# 5       13.69          light rain
# 6        6.91           clear sky
# 7        9.53    scattered clouds
# 8        9.22          few clouds
# 9        3.69          light rain

# %%
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
